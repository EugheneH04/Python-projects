# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Write Python code that prints your name, student number and email address. An example runs of the program: Bob ST1001 bob@gmail.com Exercise

# %%
print("Midhun Suresh, 47, devanmidhun0@gmail.com")
# Out:
# Midhun Suresh, 47, devanmidhun0@gmail.com

# %% [markdown]
# 2 Write Python code that prints your name, student number and email address using escape sequences. An example runs of the program: Bob ST1001 bob@gmail.com Exercise

# %%
print("Midhun Suresh,\n47,\ndevanmidhun0@gmail.com")
# Out:
# Midhun Suresh,
# 47,
# devanmidhun0@gmail.com

# %% [markdown]
# 3 Write Python code that add, subtract, multiply and divide the two numbers. You can use the two numbers 14 and 7. An example run of the program: 14 + 7 = 21 14 * 7 = 98 14 – 7 = 7 14 / 7 = 2 Exercise

# %%
a = 14
b = 7
print( a, "+", b, "=", a+b)
print( a, "-", b, "=", a-b)
print( a, "*", b, "=", a*b)
print( a, "/", b, "=", a/b)
# Out:
# 14 + 7 = 21
# 14 - 7 = 7
# 14 * 7 = 98
# 14 / 7 = 2.0

# %% [markdown]
# 4 Write Python code that displays the numbers from 1 to 5 as steps. An example runs of the program: 1 2 3 4 5.

# %%
for i in range(1,6):
    print( "\t" * (i - 1), i)
# Out:
#  1
# 	 2
# 		 3
# 			 4
# 				 5

# %% [markdown]
# 5 Write Python code that outputs the following sentence (including the quotation marks and line break) to the screen: An example runs of the program: "SDK" stands for "Software Development Kit", whereas "IDE" stands for "Integrated Development Environment".

# %%
print('An example runs of the program:"SDK" stands for "Software Development Kit"','whereas "IDE" stands for "Integrated Development Enviornment".')
# Out:
# An example runs of the program:"SDK" stands for "Software Development Kit" whereas "IDE" stands for "Integrated Development Enviornment".

# %% [markdown]
# 6 Practice and check the output print("python is an \"awesome\" language.") print("python\n\t2023")
# print('I\'m from Entri.\b')
# print("\65") print("\x65")
# print("Entri", "2023", sep="\n")
# print("Entri", "2023", sep="\b")
# print("Entri", "2023", sep="*", end="\b\b\b\b")

# %%
 print("python is an \"awesome\" language.")
 print("python\n\t2023")
 print('I\'m from Entri.\b')
 print("\65")
 print("\x65")
 print("Entri", "2023", sep="\n")
 print("Entri", "2023", sep="\b")
 print("Entri", "2023", sep="*", end="\b\b\b\b")
# Out:
# python is an "awesome" language.
# python
# 	2023
# I'm from Entri.
# 5
# e
# Entri
# 2023
# 2023
# Entri*2023

# %% [markdown]
#  7  Define the variables below. Print the types of each variable. What is the sum of your variables? (Hint: use a type conversion function.) What datatype is the sum? num=23 textnum="57" decimal=98.3

# %%
num=23
textnum="53"
decimal=98.3
print("The type of num is:",type(num))
print("The type of textnum is:",type(textnum))
print("The type of decimal is:",type(decimal))
sum = num+int(textnum)+decimal
print("The type of total sum is:",type(sum))
# Out:
# The type of num is: <class 'int'>
# The type of textnum is: <class 'str'>
# The type of decimal is: <class 'float'>
# The type of total sum is: <class 'float'>

# %% [markdown]
#  8 calculate the number of minutes in a year using variables for each unit of time. print a statement that describes what your code does also. Create three variables to store no of days in a year, minute in a hour, hours in a day, then calculate the total minutes in a year and print the values (hint) total number of minutes in an year =No.of days in an year * Hours in a day * Minutes in an hour

# %%
print("I am going ot find the no of minutes in a year for that we need three variables days_in_year,hours_in_day and minutes_in_hour \n and finally multiply these values and store in a variable minutes_in_an_year.")
days_in_year = 365
hours_in_day = 24
minutes_in_hour = 60
total_no_of_minutes = days_in_year * hours_in_day * minutes_in_hour
print("The total no of minutes in a year is:",total_no_of_minutes)
# Out:
# I am going ot find the no of minutes in a year for that we need three variables days_in_year,hours_in_day and minutes_in_hour
#  and finally multiply these values and store in a variable minutes_in_an_year.
# The total no of minutes in a year is: 525600

# %% [markdown]
# 9 Write Python code that asks the user to enter his/her name and then output/prints his/her name with a greeting. An example runs of the program: Please enter you name: Tony Hi Tony, welcome to Python programming :)

# %%
name = input("Enter your name:")
print(name,"Hi",name,"\b, welcome to Python programming:)")
# Out:
# Enter your name:midhun
# , welcome to Python programming:)

# %% [markdown]
# 10 Name your file: PoundsToDollars.py Write a program that asks the user to enter an amount in pounds (£) and the program calculates and converts an amount in dollar ($) An example runs of the program: Please enter amount in pounds: XXX £ XXX are $ XXX

# %%
Pounds = float(input("Please enter amount in pounds:"))
new_convertion = Pounds * 1.26
print(Pounds,'£ are',new_convertion,'$')
# Out:
# Please enter amount in pounds:1
# 1.0 £ are 1.26 $
