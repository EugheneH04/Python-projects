# %% [markdown]
# Python-Functions What does the len() function do in Python? Write a code example using len() to find the length of a list.

# %% [markdown]
# The length function find the length of the characters in an object such as an array ,list,stirng etc

# %%
y=input("enter your full name: ")
leng=list(y)
print("the length of your name is :",len(leng))
print(type(leng))
# Out:
# enter your full name: my name is midhun
# the length of your name is : 17
# <class 'list'>

# %% [markdown]
# Write a Python function greet(name) that takes a person's name as input and prints "Hello, [name]!".

# %%
a = input("enter your name:")
print("Hello," + a + "!")
# Out:
# enter your name:midhun
# Hello,midhun!

# %% [markdown]
# Write a Python function find_maximum(numbers) that takes a list of integers and returns the maximum value without using the built-in max() function. Use a loop to iterate through the list and compare values.

# %%
y = [1,23,43,56,32,54]
g = list(y)
print(type(g))
le = len(g)
max = 0
for i in range (le):
    if g[i]>max:
       max = g[i]
print("the max value in the list:",g,max)
# Out:
# <class 'list'>
# the max value in the list: [1, 23, 43, 56, 32, 54] 56

# %% [markdown]
# Explain the difference between local and global variables in a Python function. Write a program where a global variable and a local variable have the same name and show how Python differentiates between them.

# %% [markdown]
# A local variable is a variable that is declared inside a function and can only be accessed within that function.
# A global variable is a variable that is declared outside any function and can be accessed by any function.

# %%
x = 10 # global variable
def my_fn():
      x=3 # local variable
      print("calling local variable:",x)
my_fn()
print("calling global variable outside the fuction:",x)
# Out:
# calling local variable: 3
# calling global variable outside the fuction: 10

# %% [markdown]
# Create a function calculate_area(length, width=5) that calculates the area of a rectangle. If only the length is provided, the function should assume the width is 5. Show how the function behaves when called with and without the width argument.

# %%
def calculate_area(length,width=5):
  area = length*width
  return area
print("enter the length and breadth of the rectangle:")
l = int(input("enter the length:"))
b = int(input("enter the breadth:"))
area = calculate_area(l,b)
print("the area of the rectangle is:",area)
# Out:
# enter the length and breadth of the rectangle:
# enter the length:5
# enter the breadth:4
# the area of the rectangle is: 20
